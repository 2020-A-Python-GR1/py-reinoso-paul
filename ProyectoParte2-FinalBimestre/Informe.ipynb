# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

path="C://Users//Paulr//Documents//Git-Kraken//py-reinoso-paul//ProyectoParte2-FinalBimestre//data//raw_total_fight_data.csv"
#columnas=['R_fighter','B_fighter','R_KD','B_KD','R_SIG_STR.','B_SIG_STR.','R_SIG_STR_pct']

df1=pd.read_csv(
    path,
    nrows=10)#,
    #usecols=columnas)

# %%
df1
# Out:
#                R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR.  B_SIG_STR.  \
# 0           Henry Cejudo   Marlon Moraes     0     0   90 of 171   57 of 119
# 1   Valentina Shevchenko     Jessica Eye     1     0     8 of 11     2 of 12
# 2          Tony Ferguson  Donald Cerrone     0     0  104 of 200   68 of 185
# 3          Jimmie Rivera        Petr Yan     0     2   73 of 192   56 of 189
# 4            Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144   73 of 123
# 5         Tatiana Suarez   Nina Ansaroff     0     0   75 of 142    48 of 99
# 6      Aljamain Sterling    Pedro Munhoz     0     0  174 of 349  105 of 265
# 7  Karolina Kowalkiewicz    Alexa Grasso     0     0   90 of 232  148 of 369
# 8          Ricardo Lamas   Calvin Kattar     0     1    12 of 29    22 of 41
# 9            Yan Xiaonan     Angela Hill     0     0   94 of 249   71 of 144
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... B_GROUND  \
# 0           52%           47%    99 of 182    59 of 121  ...   1 of 1
# 1           72%           16%     37 of 40     42 of 52  ...   0 of 0
# 2           52%           36%   104 of 200    68 of 185  ...   0 of 0
# 3           38%           29%    76 of 195    58 of 192  ...  4 of 10
# 4           44%           59%    66 of 146    81 of 131  ...   6 of 6
# 5           52%           48%    95 of 166    54 of 105  ...   5 of 5
# 6           49%           39%   175 of 350   108 of 269  ...   0 of 0
# 7           38%           40%    92 of 234   163 of 384  ...   0 of 0
# 8           41%           53%     12 of 29     22 of 41  ...   4 of 5
# 9           37%           49%   105 of 264    78 of 151  ...   2 of 2
#
#                     win_by last_round last_round_time             Format  \
# 0                   KO/TKO          3            4:51  5 Rnd (5-5-5-5-5)
# 1                   KO/TKO          2            0:26  5 Rnd (5-5-5-5-5)
# 2  TKO - Doctor's Stoppage          2            5:00      3 Rnd (5-5-5)
# 3     Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 4     Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 5     Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 6     Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 7     Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 8                   KO/TKO          1            4:06      3 Rnd (5-5-5)
# 9     Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
#
#            Referee           date                location  \
# 0     Marc Goddard  June 08  2019  Chicago  Illinois  USA
# 1  Robert Madrigal  June 08  2019  Chicago  Illinois  USA
# 2  Dan Miragliotta  June 08  2019  Chicago  Illinois  USA
# 3  Kevin MacDonald  June 08  2019  Chicago  Illinois  USA
# 4  Dan Miragliotta  June 08  2019  Chicago  Illinois  USA
# 5  Robert Madrigal  June 08  2019  Chicago  Illinois  USA
# 6     Marc Goddard  June 08  2019  Chicago  Illinois  USA
# 7  Kevin MacDonald  June 08  2019  Chicago  Illinois  USA
# 8  Dan Miragliotta  June 08  2019  Chicago  Illinois  USA
# 9  Robert Madrigal  June 08  2019  Chicago  Illinois  USA
#
#                          Fight_type                Winner
# 0       UFC Bantamweight Title Bout          Henry Cejudo
# 1  UFC Women's Flyweight Title Bout  Valentina Shevchenko
# 2                  Lightweight Bout         Tony Ferguson
# 3                 Bantamweight Bout              Petr Yan
# 4                  Heavyweight Bout         Blagoy Ivanov
# 5          Women's Strawweight Bout        Tatiana Suarez
# 6                 Bantamweight Bout     Aljamain Sterling
# 7          Women's Strawweight Bout          Alexa Grasso
# 8                Featherweight Bout         Calvin Kattar
# 9          Women's Strawweight Bout           Yan Xiaonan
#
# [10 rows x 41 columns]

# %%
# Arreglando el estado aleatorio para la reproducibilidad
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
# Arreglando el estado aleatorio para la reproducibilidad
np.random.seed(19680801)

plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()
